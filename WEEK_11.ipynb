# %% [markdown]
# ### Read canadian cities csv file and list the cities where type is towns, county is *'NaN'* and  province is *'Newfoundland and Labrador'*

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np
a = pd.read_csv("ca-cities-sample.csv")
a[
    (a["type"] == "Town")
    & (a["county"].isna())
    & (a["province"] == "Newfoundland and Labrador")
]
# Out:
#         id               name county                   province province_code  \
# 216  25465         Terra Nova    NaN  Newfoundland and Labrador            NL
# 237  25486      Terrenceville    NaN  Newfoundland and Labrador            NL
# 501  25750          Tilt Cove    NaN  Newfoundland and Labrador            NL
# 602  25851             Torbay    NaN  Newfoundland and Labrador            NL
# 694  25943           Traytown    NaN  Newfoundland and Labrador            NL
# 723  25972          Trepassey    NaN  Newfoundland and Labrador            NL
# 733  25982            Trinity    NaN  Newfoundland and Labrador            NL
# 736  25985  Trinity Bay North    NaN  Newfoundland and Labrador            NL
# 745  25994             Triton    NaN  Newfoundland and Labrador            NL
# 773  26022        Trout River    NaN  Newfoundland and Labrador            NL
# 900  26149        Twillingate    NaN  Newfoundland and Labrador            NL
#
# ...

# %%
# Your code here

# %% [markdown]
# ### Show the list of the cities with latitude > 55 and longitude < -111 and with unique timezones

# %%
# Your code here
import pandas as pd
import numpy as np
a = pd.read_csv("ca-cities-sample.csv")
a[(a["latitude"] >55) & (a["longitude"] < -111)].drop_duplicates(subset=["time_zone"])
# Out:
#         id          name            county               province  \
# 20   25269        Tagish               NaN                  Yukon
# 21   25270       Tahltan   Kitimat-Stikine       British Columbia
# 46   25295      Tamarack       Peace River       British Columbia
# 53   25302       Tangent               NaN                Alberta
# 546  25795    Toad River  Northern Rockies       British Columbia
# 801  26050  Tsiigehtchic               NaN  Northwest Territories
#
#     province_code postcode_area      type map_reference  latitude  longitude  \
# 20             YT           Y0B  Locality        105D08  60.31484 -134.27151
# 21             BC           V0C  Locality        104J02  58.01667 -131.00000
# 46             BC           V0C  Locality        094H11  57.65000 -121.16667
# 53             AB           T0H  Locality        083N13  55.79861 -117.67889
# 546            BC           V0C  Locality        094K14  58.85000 -125.23333
# ...

# %% [markdown]
# ### Depict only most 3 frequent numbers

# %%
np.random.RandomState(100)
ser = pd.Series(np.random.randint(1, 5, [12]))

# %%
# Your code here
ser.value_counts().sort_values(ascending=False).iloc[:3]
# Out:
# 1    4
# 2    4
# 3    3
# dtype: int64

# %% [markdown]
# ### Import every 37th row of housing dataset as a dataframe with population greater or equal to 800, median house value is less than 123456 and median income is less than 4, and not inland. Show the total bedrooms, total rooms, and ocean proximity of the imported data filtered by median_house_value in ascending order.

# %%
# Your code here
filter_ = housing_df_37.loc[
    (housing_df_37["population"] >= 800)
    & (housing_df_37["median_house_value"] < 123456)
    & (housing_df_37["median_income"] < 4)
    & (housing_df_37["ocean_proximity"] != "INLAND")
]

filter_.sort_values(by=["median_house_value"], ascending=True)[
    ["median_house_value", "total_rooms", "total_bedrooms", "ocean_proximity"]
]
# Out:
#        median_house_value  total_rooms  total_bedrooms ocean_proximity
# 15651             55000.0       2302.0           938.0        NEAR BAY
# 2553              70200.0       1453.0           293.0      NEAR OCEAN
# 2590              74100.0       1982.0           495.0      NEAR OCEAN
# 9768              76600.0       1054.0           269.0       <1H OCEAN
# 14245             86300.0       2002.0           488.0      NEAR OCEAN
# 5217              87500.0       2667.0           671.0       <1H OCEAN
# 14763             87500.0       2350.0           667.0      NEAR OCEAN
# 18870             88700.0       2161.0           440.0        NEAR BAY
# 296               90600.0       1594.0           367.0        NEAR BAY
# 5069              91400.0       1701.0           452.0       <1H OCEAN
# 5180              94600.0       1481.0           329.0       <1H OCEAN
# 4995              96500.0       2637.0           588.0       <1H OCEAN
# ...
